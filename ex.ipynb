# %%
import pandas as pd
import json

# %%
path = r'.\informacoes.json'

# %%
info = pd.read_json(path)
info
# Out:
#    nome  idade                                          enderecos
# 0  João     28  {'tipo': 'casa', 'rua': 'Rua A', 'numero': 123...
# 1  João     28  {'tipo': 'trabalho', 'rua': 'Rua B', 'numero':...

# %%
with open('informacoes.json') as f:
    raw_json = json.load(f)

raw_json
# Out:
# {'nome': 'JoÃ£o',
#  'idade': 28,
#  'enderecos': [{'tipo': 'casa',
#    'rua': 'Rua A',
#    'numero': 123,
#    'cidade': 'SÃ£o Paulo'},
#   {'tipo': 'trabalho',
#    'rua': 'Rua B',
#    'numero': 456,
#    'cidade': 'Rio de Janeiro'}]}

# %%
raw_json = pd.json_normalize(raw_json, record_path='enderecos', meta=['nome', 'idade'])
raw_json
# Out:
#        tipo    rua  numero          cidade   nome idade
# 0      casa  Rua A     123      SÃ£o Paulo  JoÃ£o    28
# 1  trabalho  Rua B     456  Rio de Janeiro  JoÃ£o    28

# %%
path_2 = r'.\cursos_cadastrados.json'
df_cursos = pd.read_json(path_2)
df_cursos
# Out:
#                              curso      categoria carga_horaria concluintes  \
# 0         Introdução à programação    Programação      20 horas         100
# 1            Excel para iniciantes  Produtividade          None        None
# 2  Marketing digital para negócios      Marketing      30 horas          75
# 3          Inteligência artificial    Programação      40 horas
# 4             Inglês para negócios        Idiomas      20 horas          30
# 5         Introdução à programação    Programação      20 horas         100
#
#   data_inicio data_conclusao  \
# 0  2022-01-01     2022-01-20
# 1        None           None
# 2  2022-03-01     2022-03-31
# 3  2022-04-01
# 4
# 5  2022-01-01     2022-01-20
#
#                                            descricao  preco  \
# 0        Curso introdutório à programação com Python   99.9
# 1                                               None    NaN
# 2                    Curso introdutório em marketing   89.9
# ...

# %%
with open('cursos_cadastrados.json', encoding='utf-8') as f:
    rj = json.load(f)

df_cursos = pd.json_normalize(rj)
df_cursos
# Out:
#                              curso      categoria carga_horaria concluintes  \
# 0         Introdução à programação    Programação      20 horas         100
# 1            Excel para iniciantes  Produtividade          None        None
# 2  Marketing digital para negócios      Marketing      30 horas          75
# 3          Inteligência artificial    Programação      40 horas
# 4             Inglês para negócios        Idiomas      20 horas          30
# 5         Introdução à programação    Programação      20 horas         100
#
#   data_inicio data_conclusao  \
# 0  2022-01-01     2022-01-20
# 1        None           None
# 2  2022-03-01     2022-03-31
# 3  2022-04-01
# 4
# 5  2022-01-01     2022-01-20
#
#                                            descricao  preco  instrutor.nome  \
# 0        Curso introdutório à programação com Python  99.90      João Silva
# 1                                               None   None  Maria Oliveira
# ...

# %%
df_cursos.isna().sum()
# Out:
# curso                 0
# categoria             0
# carga_horaria         1
# concluintes           1
# data_inicio           1
# data_conclusao        1
# descricao             1
# preco                 1
# instrutor.nome        0
# instrutor.email       0
# instrutor.telefone    0
# dtype: int64

# %%
df_cursos = df_cursos.dropna()
df_cursos.isna().sum()
# Out:
# curso                 0
# categoria             0
# carga_horaria         0
# concluintes           0
# data_inicio           0
# data_conclusao        0
# descricao             0
# preco                 0
# instrutor.nome        0
# instrutor.email       0
# instrutor.telefone    0
# dtype: int64

# %%
df_cursos
# Out:
#                              curso    categoria carga_horaria concluintes  \
# 0         Introdução à programação  Programação      20 horas         100
# 2  Marketing digital para negócios    Marketing      30 horas          75
# 3          Inteligência artificial  Programação      40 horas
# 4             Inglês para negócios      Idiomas      20 horas          30
# 5         Introdução à programação  Programação      20 horas         100
#
#   data_inicio data_conclusao  \
# 0  2022-01-01     2022-01-20
# 2  2022-03-01     2022-03-31
# 3  2022-04-01
# 4
# 5  2022-01-01     2022-01-20
#
#                                            descricao  preco instrutor.nome  \
# 0        Curso introdutório à programação com Python  99.90     João Silva
# 2                    Curso introdutório em marketing   89.9     Ana Santos
# 3  Curso avançado sobre inteligência artificial c...  129.9
# 4                      Curso de inglês para negócios   69.9     John Smith
# ...

# %%
spaces = df_cursos.applymap(lambda x: isinstance(x, str) and x.isspace())
spaces
# Out:
# C:\Users\corre\AppData\Local\Temp\ipykernel_2576\1166769479.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   spaces = df_cursos.applymap(lambda x: isinstance(x, str) and x.isspace())
#    curso  categoria  carga_horaria  concluintes  data_inicio  data_conclusao  \
# 0  False      False          False        False        False           False
# 2  False      False          False        False        False           False
# 3  False      False          False        False        False           False
# 4  False      False          False        False        False           False
# 5  False      False          False        False        False           False
#
#    descricao  preco  instrutor.nome  instrutor.email  instrutor.telefone
# 0      False  False           False            False               False
# 2      False  False           False            False               False
# ...

# %%
df_cursos
# Out:
#                              curso    categoria carga_horaria concluintes  \
# 0         Introdução à programação  Programação      20 horas         100
# 2  Marketing digital para negócios    Marketing      30 horas          75
# 3          Inteligência artificial  Programação      40 horas
# 4             Inglês para negócios      Idiomas      20 horas          30
# 5         Introdução à programação  Programação      20 horas         100
#
#   data_inicio data_conclusao  \
# 0  2022-01-01     2022-01-20
# 2  2022-03-01     2022-03-31
# 3  2022-04-01
# 4
# 5  2022-01-01     2022-01-20
#
#                                            descricao  preco instrutor.nome  \
# 0        Curso introdutório à programação com Python  99.90     João Silva
# 2                    Curso introdutório em marketing   89.9     Ana Santos
# 3  Curso avançado sobre inteligência artificial c...  129.9
# 4                      Curso de inglês para negócios   69.9     John Smith
# ...

# %% [markdown]
# Mais um

# %%
# criando um DataFrame com 30 transações aleatórias
df_banco = pd.DataFrame({
    'ID da transação': range(1, 31),
    'Valor da transação': [100, 200, 150, 500, 300, 913, 250, 400, 200, 150, 
                           200, 200, 400, 300, 150, 301, 805, 300, 400, 250, 
                           150, 100, 500, 600, 200, 350, 100, 250, 800, 250],
    'Data da transação': pd.date_range(start='2022-01-01', end='2022-01-30', freq='D'),
    'Local da transação': ['São Paulo, Brasil', 'Rio de Janeiro, Brasil', 'Belo Horizonte, Brasil', 'São Paulo, Brasil', 
                           'São Paulo, Brasil', 'Nova Iorque, EUA', 'São Paulo, Brasil', 'São Paulo, Brasil', 'São Paulo, Brasil',
                           'Rio de Janeiro, Brasil', 'São Paulo, Brasil', 'São Paulo, Brasil', 'São Paulo, Brasil', 'São Paulo, Brasil',
                           'São Paulo, Brasil', 'São Paulo, Brasil', 'Los Angeles, EUA', 'São Paulo, Brasil', 'São Paulo, Brasil', 'São Paulo, Brasil',
                           'São Paulo, Brasil', 'São Paulo, Brasil', 'São Paulo, Brasil', 'São Paulo, Brasil', 'São Paulo, Brasil', 'São Paulo, Brasil',
                           'São Paulo, Brasil', 'São Paulo, Brasil', 'Miami, EUA', 'São Paulo, Brasil']
})

# %%
df_banco
# Out:
#     ID da transação  Valor da transação Data da transação  \
# 0                 1                 100        2022-01-01
# 1                 2                 200        2022-01-02
# 2                 3                 150        2022-01-03
# 3                 4                 500        2022-01-04
# 4                 5                 300        2022-01-05
# 5                 6                 913        2022-01-06
# 6                 7                 250        2022-01-07
# 7                 8                 400        2022-01-08
# 8                 9                 200        2022-01-09
# 9                10                 150        2022-01-10
# 10               11                 200        2022-01-11
# 11               12                 200        2022-01-12
# 12               13                 400        2022-01-13
# 13               14                 300        2022-01-14
# 14               15                 150        2022-01-15
# ...

# %%
def calc_out(df, coluna):
    Q1 = df[coluna].quantile(.25)
    Q3 = df[coluna].quantile(.75)
    IQR = Q3 - Q1
    inferior = Q1 - 1.5*IQR
    superior = Q3 + 1.5*IQR
    indice = (df[coluna] < inferior) | (df[coluna] > superior)
    return df_banco[indice][coluna]

# %%
calc_out(df_banco, 'Valor da transação')
# Out:
# 5     913
# 16    805
# 28    800
# Name: Valor da transação, dtype: int64
